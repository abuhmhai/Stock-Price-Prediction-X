# %% [markdown]
# <a href="https://colab.research.google.com/github/amanjain252002/Stock-Price-Prediction/blob/main/Data_Preprocessing_And_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data Loading

# %%
ACB = pd.read_csv("./Database/ACB.csv")
BIDV = pd.read_csv("./Database/BIDV.csv")
BVH = pd.read_csv("./Database/BVH.csv")
CTG = pd.read_csv("./Database/CTG.csv")
FPT = pd.read_csv("./Database/FPT.csv")

# %% [markdown]
# ## ACB

# %%
ACB.head()
# Out:
#                    Date    Open    High     Low  Adj. Close   Volume
# 0  1/2/2019 12:00:00 AM  11.703  11.693  11.416      11.544  1103106
# 1  1/3/2019 12:00:00 AM  10.398  11.360  10.267      11.110  1956382
# 2  1/4/2019 12:00:00 AM  11.070  11.413  11.052      11.189  2771983
# 3  1/7/2019 12:00:00 AM  11.426  11.402  11.244      11.347  1305819
# 4  1/8/2019 12:00:00 AM  12.414  12.378  11.235      11.268   846226

# %%
ACB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1427 entries, 0 to 1426
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1427 non-null   object
#  1   Open        1427 non-null   float64
#  2   High        1427 non-null   float64
#  3   Low         1427 non-null   float64
#  4   Adj. Close  1427 non-null   float64
#  5   Volume      1427 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 67.0+ KB

# %%
# Drop NULL rows
ACB.dropna(inplace = True)

# %%
# Change Dtype of Columns
ACB["Date"] = pd.to_datetime(ACB["Date"])
ACB = ACB.astype({"Open": float, "Volume": float})
# Out:
# /var/folders/02/1bct3b017798nsbmvhbtst9c0000gn/T/ipykernel_68913/2970335893.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ACB["Date"] = pd.to_datetime(ACB["Date"])

# %%
# Sort the Database by Date
ACB = ACB.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
ACB = ACB[ACB["Date"] >= '2019-01-01'].reset_index(drop = True)

# %%
ACB.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1427  1427.000000  1427.000000  1427.000000
# mean   2021-11-06 03:27:24.849334272    18.020413    18.221575    17.815934
# min              2019-01-02 00:00:00     6.951000     8.117000     6.951000
# 25%              2020-06-10 12:00:00    11.782000    11.900000    11.596500
# 50%              2021-11-02 00:00:00    20.214000    20.381000    19.940000
# 75%              2023-04-08 12:00:00    22.300000    22.493000    22.051000
# max              2024-09-12 00:00:00    29.700000    30.200000    29.300000
# std                              NaN     5.753658     5.785576     5.714020
#
#         Adj. Close        Volume
# count  1427.000000  1.427000e+03
# mean     18.018019  5.778603e+06
# min       7.685000  2.820880e+05
# 25%      11.703000  2.323900e+06
# 50%      20.088000  4.548000e+06
# 75%      22.300000  7.932850e+06
# max      29.650000  3.515600e+07
# std       5.747765  4.745279e+06

# %%
# Lưu lại file CSV với định dạng mới
ACB.to_csv("./Database/Pre_Processed_ACB.csv", index=False)

# %% [markdown]
# ## BIDV

# %%
BIDV.head()
# Out:
#                    Date    Open    High     Low  Adj. Close   Volume
# 0  1/2/2019 12:00:00 AM  22.968  22.968  22.334      22.367   805700
# 1  1/3/2019 12:00:00 AM  22.367  22.568  21.366      21.366  1107500
# 2  1/4/2019 12:00:00 AM  21.032  21.333  20.565      21.065  1457300
# 3  1/7/2019 12:00:00 AM  21.366  22.034  21.366      21.566   806060
# 4  1/8/2019 12:00:00 AM  21.767  21.767  21.299      21.366   558540

# %%
BIDV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1422 non-null   object
#  1   Open        1422 non-null   float64
#  2   High        1422 non-null   float64
#  3   Low         1422 non-null   float64
#  4   Adj. Close  1422 non-null   float64
#  5   Volume      1422 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 66.8+ KB

# %%
# Drop NULL rows
BIDV.dropna(inplace = True)

# %%
# Change Dtype of Columns
BIDV["Date"] = pd.to_datetime(BIDV["Date"])
BIDV = BIDV.astype({"Open": float, "Volume": float})
# Out:
# /var/folders/02/1bct3b017798nsbmvhbtst9c0000gn/T/ipykernel_68913/2757931331.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   BIDV["Date"] = pd.to_datetime(BIDV["Date"])

# %%
# Sort the Database by Date
BIDV = BIDV.sort_values(by = 'Date', ignore_index = True)

# %%
BIDV = BIDV[BIDV["Date"] >= '2019-01-01'].reset_index(drop = True)

# %%
# Lưu lại file CSV với định dạng mới
BIDV.to_csv("./Database/Pre_Processed_BIDV.csv", index=False)

# %%
BIDV.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1422  1422.000000  1422.000000  1422.000000
# mean   2021-11-07 07:51:53.924050688    33.447274    33.925553    33.004392
# min              2019-01-02 00:00:00    20.431000    21.032000    20.373000
# 25%              2020-06-09 06:00:00    27.766000    28.074000    27.478000
# 50%              2021-11-04 12:00:00    31.502000    31.892500    30.970000
# 75%              2023-04-10 18:00:00    39.223000    39.666000    38.779000
# max              2024-09-12 00:00:00    54.400000    56.700000    53.500000
# std                              NaN     8.022652     8.113795     7.921020
#
#         Adj. Close        Volume
# count  1422.000000  1.422000e+03
# mean     33.436028  1.731043e+06
# min      20.431000  1.635640e+05
# 25%      27.694000  9.269442e+05
# 50%      31.462000  1.437235e+06
# 75%      39.256000  2.131495e+06
# max      54.400000  1.302750e+07
# std       7.991849  1.215692e+06

# %% [markdown]
# ## BVH

# %%
BVH.head()
# Out:
#                    Date    Open    High     Low  Adj. Close  Volume
# 0  1/2/2019 12:00:00 AM  79.787  79.787  78.119      78.119   87080
# 1  1/3/2019 12:00:00 AM  79.436  79.875  77.593      78.295   55310
# 2  1/4/2019 12:00:00 AM  78.295  78.295  75.486      77.768   96940
# 3  1/7/2019 12:00:00 AM  78.558  79.699  76.978      77.768   92970
# 4  1/8/2019 12:00:00 AM  77.768  77.768  77.241      77.417   36610

# %%
BVH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1422 non-null   object
#  1   Open        1422 non-null   float64
#  2   High        1422 non-null   float64
#  3   Low         1422 non-null   float64
#  4   Adj. Close  1422 non-null   float64
#  5   Volume      1422 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 66.8+ KB

# %%
# Drop NULL rows
BVH.dropna(inplace = True)

# %%
# Change Dtype of Columns
BVH["Date"] = pd.to_datetime(BIDV["Date"])
BVH  = BVH.astype({"Open": float, "Volume": float})

# %%
# Sort the Database by Date
BVH = BVH.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
BVH = BVH[BVH["Date"] >= '2019-01-01'].reset_index(drop = True)

# %%
BVH.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1422  1422.000000  1422.000000  1422.000000
# mean   2021-11-07 07:51:53.924050688    51.724443    52.391916    51.074511
# min              2019-01-02 00:00:00    29.365000    30.744000    28.742000
# 25%              2020-06-09 06:00:00    44.000000    44.526000    43.495500
# 50%              2021-11-04 12:00:00    48.754000    49.446000    47.986000
# 75%              2023-04-10 18:00:00    55.592500    56.313000    54.428250
# max              2024-09-12 00:00:00    86.282000    86.458000    85.405000
# std                              NaN    10.979701    11.055132    10.890052
#
#         Adj. Close        Volume
# count  1422.000000  1.422000e+03
# mean     51.683160  7.581695e+05
# min      28.742000  1.456000e+04
# 25%      43.986000  2.781770e+05
# 50%      48.663000  6.143450e+05
# 75%      55.412250  1.033405e+06
# max      86.282000  4.575300e+06
# std      10.977367  6.395353e+05

# %%
# Lưu lại file CSV với định dạng mới
BVH.to_csv("./Database/Pre_Processed_BVH.csv", index=False)

# %% [markdown]
# ## FPT

# %%
FPT.head()
# Out:
#                    Date    Open    High     Low  Adj. Close  Volume
# 0  1/2/2019 12:00:00 AM  18.247  18.400  17.964      17.985  459120
# 1  1/3/2019 12:00:00 AM  18.095  18.095  17.767      17.811  716600
# 2  1/4/2019 12:00:00 AM  17.723  18.095  17.680      17.942  318570
# 3  1/7/2019 12:00:00 AM  18.247  18.378  18.160      18.247  408470
# 4  1/8/2019 12:00:00 AM  18.247  18.335  18.204      18.335  295660

# %%
FPT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1422 non-null   object
#  1   Open        1422 non-null   float64
#  2   High        1422 non-null   float64
#  3   Low         1422 non-null   float64
#  4   Adj. Close  1422 non-null   float64
#  5   Volume      1422 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 66.8+ KB

# %%
# Drop NULL rows
FPT.dropna(inplace = True)

# %%
# Change Dtype of Columns
FPT["Date"] = pd.to_datetime(FPT["Date"])
FPT = FPT.astype({"Open": float, "Volume": float})
# Out:
# /var/folders/02/1bct3b017798nsbmvhbtst9c0000gn/T/ipykernel_68913/654357832.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   FPT["Date"] = pd.to_datetime(FPT["Date"])

# %%
# Sort the Database by Date
FPT = FPT.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
FPT = FPT[FPT["Date"] >= '2019-01-01'].reset_index(drop = True)

# %%
FPT.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1422  1422.000000  1422.000000  1422.000000
# mean   2021-11-07 07:51:53.924050688    52.509653    53.101292    51.967397
# min              2019-01-02 00:00:00    17.266000    17.522000    17.095000
# 25%              2020-06-09 06:00:00    24.428000    24.604750    24.215000
# 50%              2021-11-04 12:00:00    55.283000    55.793000    54.714000
# 75%              2023-04-10 18:00:00    63.101000    63.814500    62.401250
# max              2024-09-12 00:00:00   139.100000   139.700000   137.500000
# std                              NaN    29.164217    29.495686    28.856047
#
#         Adj. Close        Volume
# count  1422.000000  1.422000e+03
# mean     52.544646  2.055031e+06
# min      17.223000  1.414800e+05
# 25%      24.372000  1.052332e+06
# 50%      55.229500  1.639878e+06
# 75%      63.010000  2.514278e+06
# max     139.600000  1.372370e+07
# std      29.185744  1.584532e+06

# %%
# Lưu lại file CSV với định dạng mới
FPT.to_csv("./Database/Pre_Processed_FPT.csv", index=False)

# %% [markdown]
# ## CTG

# %%
CTG.head()
# Out:
#                    Date    Open    High     Low  Adj. Close   Volume
# 0  1/2/2019 12:00:00 AM  12.844  12.978  12.677      12.677  2420340
# 1  1/3/2019 12:00:00 AM  12.677  12.811  12.043      12.077  5513360
# 2  1/4/2019 12:00:00 AM  12.043  12.377  11.810      12.244  3804290
# 3  1/7/2019 12:00:00 AM  12.544  12.544  12.110      12.110  3982660
# 4  1/8/2019 12:00:00 AM  12.177  12.177  11.877      11.943  5636280

# %%
CTG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1422 non-null   object
#  1   Open        1422 non-null   float64
#  2   High        1422 non-null   float64
#  3   Low         1422 non-null   float64
#  4   Adj. Close  1422 non-null   float64
#  5   Volume      1422 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 66.8+ KB

# %%
# Drop NULL rows
CTG.dropna(inplace = True)

# %%
# Change Dtype of Columns
CTG["Date"] = pd.to_datetime(CTG["Date"])

CTG = CTG.astype({"Open": float, "High": float, "Low": float,  "Adj. Close": float, "Volume": float})
# Out:
# /var/folders/02/1bct3b017798nsbmvhbtst9c0000gn/T/ipykernel_68913/682700116.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   CTG["Date"] = pd.to_datetime(CTG["Date"])

# %%
# Sort the Database by Date
CTG = CTG.sort_values(by = 'Date', ignore_index = True)

# %%
# Drop rows having Date < '2015-01-01'
CTG = CTG[CTG["Date"] >= '2019-01-01'].reset_index(drop = True)

# %%
CTG.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1422  1422.000000  1422.000000  1422.000000
# mean   2021-11-07 07:51:53.924050688    23.570061    23.886610    23.258352
# min              2019-01-02 00:00:00    11.343000    12.010000    11.076000
# 25%              2020-06-09 06:00:00    15.755250    16.014000    15.513000
# 50%              2021-11-04 12:00:00    25.302500    25.565500    24.967000
# 75%              2023-04-10 18:00:00    28.726000    29.086250    28.407000
# max              2024-09-12 00:00:00    36.885000    37.156000    36.411000
# std                              NaN     6.932727     7.004986     6.829044
#
#         Adj. Close        Volume
# count  1422.000000  1.422000e+03
# mean     23.559386  7.044763e+06
# min      11.476000  9.108000e+05
# 25%      15.721500  3.285354e+06
# 50%      25.280000  5.758486e+06
# 75%      28.673500  9.015734e+06
# max      36.817000  3.512210e+07
# std       6.921110  5.140616e+06

# %%
# Lưu lại file CSV với định dạng mới
CTG.to_csv("./Database/Pre_Processed_CTG.csv", index=False)

# %% [markdown]
# #Exploratory Data Analysis

# %%
Companies = [ACB, BIDV, BVH, FPT, CTG]
Companies_Title = ["ACB", "BIDV", "BVH", "FPT", "CTG"]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Giả sử Companies là một danh sách các DataFrame và Companies_Title là danh sách tiêu đề tương ứng
# Đảm bảo cột Date là datetime và Adj. Close là float
for company in Companies:
    # Chuyển cột Date sang định dạng datetime
    company['Date'] = pd.to_datetime(company['Date'], errors='coerce')
    
    # Đảm bảo cột Adj. Close là float (nếu có dấu phẩy, chuyển về dạng số float)
    company['Adj. Close'] = pd.to_numeric(company['Adj. Close'], errors='coerce')

# Vẽ biểu đồ
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
    plt.subplot(3, 2, index + 1)
    
    # Kiểm tra dữ liệu đã được chuyển đổi chính xác
    plt.plot(company["Date"], company["Adj. Close"])
    plt.title(Companies_Title[index])
    plt.ylabel('Adj. Close')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see from the  above graph that Telsa shares have tremendous growth in the 2020-2021 period.
#
# If we follow the news, it can be due to
#
#
# 1.   Emission Credit Sales
# 2.   Tesla entering the Fast-Growing Compact SUV Market
# 3.   Starting production in China
#
# For the rest of the Companies, we can see that COVID-19 is the primary factor affecting the 2020-2021 period.

# %%
# Now lets plot the total volume of stock being traded each day 

plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Volume"])
  plt.title(Companies_Title[index])
  plt.ylabel('Volume')

# %% [markdown]
# Now, we have seen the visualizations for the closing price and volume traded each day, let's go ahead and calculate the moving average of the stock.

# %% [markdown]
# ### What was the moving average of the various stocks ?

# %%
Moving_Average_Day = [10, 20, 50]
for Moving_Average in Moving_Average_Day:
  for company in Companies:
    column_name = f'Moving Average for {Moving_Average} days'
    company[column_name] = company["Adj. Close"].rolling(Moving_Average).mean()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Adj. Close"])
  plt.plot(company["Date"], company["Moving Average for 10 days"])
  plt.plot(company["Date"], company["Moving Average for 20 days"])
  plt.plot(company["Date"], company["Moving Average for 50 days"])
  plt.title(Companies_Title[index])
  plt.legend(("Adj. Close", "Moving Average for 10 days", "Moving Average for 20 days", "Moving Average for 50 days"))

# %% [markdown]
# ### What was the daily return of the stock on average ?

# %% [markdown]
# Now that we've done some baseline analysis, let's go ahead and dive a little deeper. We're now going to analyze the risk of the stock. In order to do so we'll need to take a closer look at the daily changes of the stock, and not just its absolute value.

# %%
# pct_change() function calculates the percentage change between the current and a prior element.
# This function by default calculates the percentage change from the immediately previous row. 

for company in Companies:
  company["Daily Return"] = company["Adj. Close"].pct_change()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Daily Return"])
  plt.title(Companies_Title[index])
  plt.ylabel('Daily Return')

# %% [markdown]
# Now, let's get an overall at the average daily return using a histogram.

# %%
# distplot is a deprecated function, so to ignore warnings, the filterwarnings function is used.

import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(20, 15))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color = "purple")
  plt.title(Companies_Title[index])

# %% [markdown]
# Kurtosis is a statistical measure that defines how heavily the tails of a distribution differ from the tails of a normal distribution. In other words kurtosis identifies whether the tails of a given distribution contain extreme values.

# %%
print("Kurtosis Value")
for index, company in enumerate(Companies):
  print(f'{Companies_Title[index]}: {company["Daily Return"].kurtosis()}')
# Out:
# Kurtosis Value
# ACB: 269.7421822757827
# BIDV: 2.0010512578442032
# BVH: 2.360690281749055
# FPT: 6.09469470092938
# CTG: 2.0748381906276343

# %% [markdown]
# The above graph and the positive kurtosis value indicate that getting extreme daily return values is rare.

# %% [markdown]
# ### What was the correlation between diffrent stocks closing price ?

# %%
# Companies_return contain closing price of all the companies
Companies_returns = pd.DataFrame()
Companies_returns["ACB"] = ACB["Adj. Close"]
Companies_returns["BIDV"] = BIDV["Adj. Close"]
Companies_returns["BVH"] = BVH["Adj. Close"]
Companies_returns["FPT"] = FPT["Adj. Close"]
Companies_returns["CTG"] = CTG["Adj. Close"]
Companies_returns.head()
# Out:
#       ACB    BIDV     BVH     FPT     CTG
# 0  11.544  22.367  78.119  17.985  12.677
# 1  11.110  21.366  78.295  17.811  12.077
# 2  11.189  21.065  77.768  17.942  12.244
# 3  11.347  21.566  77.768  18.247  12.110
# 4  11.268  21.366  77.417  18.335  11.943

# %%
# Companies_Daily_returns contains percentage daily returns of all the companies
Companies_Daily_returns = Companies_returns.pct_change()
Companies_Daily_returns.head()
# Out:
#         ACB      BIDV       BVH       FPT       CTG
# 0       NaN       NaN       NaN       NaN       NaN
# 1 -0.037595 -0.044753  0.002253 -0.009675 -0.047330
# 2  0.007111 -0.014088 -0.006731  0.007355  0.013828
# 3  0.014121  0.023784  0.000000  0.016999 -0.010944
# 4 -0.006962 -0.009274 -0.004513  0.004823 -0.013790

# %% [markdown]
# Now, let's do a correlation plot, to get actual numerical values for the correlation between the stocks closing price

# %%
sns.heatmap(Companies_returns.corr(), annot=True, cmap="Reds")
# Out:
# <Axes: >

# %% [markdown]
# Finally, let's do a correlation plot, to get actual numerical values for the correlation between the stocks daily returns.

# %%
sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="Reds")
# Out:
# <Axes: >

# %% [markdown]
# From the above plot, we can see that Microsoft and Google had the strongest correlation in stocks daily returns.

# %% [markdown]
# ### How much value do we put at risk by investing in a paticular stock ?

# %% [markdown]
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
Returns = Companies_Daily_returns.dropna()

plt.figure(figsize=(20, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(Companies_Title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (10, 0), textcoords = 'offset points')

# %%
import datetime

# Unix timestamp
timestamp = 1727395200

# Chuyển đổi sang định dạng 10/21/2022 00:00:00
date_time = datetime.datetime.fromtimestamp(timestamp)
formatted_time = date_time.strftime('%m/%d/%Y %H:%M:%S')

print(formatted_time)
# Out:
# 09/27/2024 07:00:00

# %% [markdown]
# From the above graph, we can see that Tesla has the highest expected returns and the highest risk factor. Google has the lowest expected returns and the lowest risk factor.
